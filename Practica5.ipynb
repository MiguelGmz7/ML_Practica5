# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelGmz7/ML_Practica5/blob/main/Practica5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica 5
#
# Utilizar el dataset "productos.csv" para realizar un modelo de regresion lineal bajo las siguientes caracteristicas

# %%
################################
## Import required Librarires ##
################################
# Numpy to compute #
import numpy as np

# Matplotlib to show the results ##
import matplotlib.pyplot as plt
import pandas as pd

# Scikit learn to make the regression model #
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
####################################
## Read the dataset (Format .csv) ##
####################################
df = pd.read_csv("Productos.csv", decimal=',')
df.head(10)
# Out:
#    Semana  Horas Trabajadas  Horas Descanso  Productos Terminados
# 0       1                42               2                  28.9
# 1       2                45               3                  30.6
# 2       3                30               2                  21.1
# 3       4                33               2                  21.8
# 4       5                33               3                  19.3
# 5       6                37               3                  26.3
# 6       7                39               2                  28.1
# 7       8                49               2                  28.4
# 8       9                48               2                  29.4
# 9      10                34               2                  21.1

# %%
##########################
## Datset Preprocessing ##
##########################
df = df.dropna(subset=['Semana','Horas Trabajadas', 'Horas Descanso', 'Productos Terminados'])

# %% [markdown]
# # Seleccionamos nuestras variables dependientes e independientes

# %%
x = df["Horas Trabajadas"].astype(float)
y = df["Productos Terminados"].astype(float)

x = [[i] for i in x]
y = [[i] for i in y]

# %% [markdown]
# # Entrenamos los datos

# %%
model = LinearRegression()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
print(y_pred[0:10])
# Out:
# [[27.78595679]
#  [20.70040509]
#  [28.33099923]
#  [29.96612654]
#  [29.4210841 ]
#  [24.51570216]
#  [29.96612654]
#  [19.61032022]
#  [19.61032022]
#  [29.96612654]]

# %%
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 3.027805219541251

# %%
plt.scatter(x_test, y_test, color="blue", label="Real Data")
# Plot the linear regression #
plt.scatter(x_test, y_pred, color="magenta", linewidth=2, label="Prediction")
# Plot predictions obtained by the model #
plt.plot(x_test, y_pred, color="black", linewidth=2, label="Linear regression")

plt.xlabel("Horas Trabajadas")
plt.ylabel("Productos Terminados")
plt.legend()
plt.show()

# %%
list = [20, 38, 42, 55, 80, 14]

for i in list:
  value = i*model.coef_[0][0] + model.intercept_[0] # xm + b
  print(f"Para un total de {i} trabajadas, el valor de productos terminados predecido es de {value}")
# Out:
# Para un total de 20 trabajadas, el valor de productos terminados predecido es de 14.159895833333335
# Para un total de 38 trabajadas, el valor de productos terminados predecido es de 23.970659722222223
# Para un total de 42 trabajadas, el valor de productos terminados predecido es de 26.15082947530864
# Para un total de 55 trabajadas, el valor de productos terminados predecido es de 33.2363811728395
# Para un total de 80 trabajadas, el valor de productos terminados predecido es de 46.86244212962963
# Para un total de 14 trabajadas, el valor de productos terminados predecido es de 10.889641203703707
